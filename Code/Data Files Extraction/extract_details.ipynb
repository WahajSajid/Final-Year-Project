# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Wahaj Sajid\Desktop\Final-Year-Project\Code\Tumor Centered Crop Model Trained\training_brats2024_tumor_centered_patching.txt")
latest = df.iloc[-1]

train_cols = ['dice_ET','dice_NETC','dice_RC','dice_SNFH','dice_bg','dice_coef','dice_tumor_core','dice_whole_tumor']
val_cols   = ['val_dice_ET','val_dice_NETC','val_dice_RC','val_dice_SNFH','val_dice_bg','val_dice_coef','val_dice_tumor_core','val_dice_whole_tumor']

print(f"Epoch: {int(latest['epoch'])}\n")
print("Training:")
for c in train_cols:
    print(f"  {c}: {latest[c]:.4f}")

print("\nValidation:")
for c in val_cols:
    print(f"  {c}: {latest[c]:.4f}")
# Out:
# Epoch: 81
#
# Training:
#   dice_ET: 0.3442
#   dice_NETC: 0.9031
#   dice_RC: 0.7917
#   dice_SNFH: 0.8873
#   dice_bg: 0.9968
#   dice_coef: 0.6420
#   dice_tumor_core: 0.8939
#   dice_whole_tumor: 0.9098
#
# Validation:
#   val_dice_ET: 0.4547
#   val_dice_NETC: 0.8733
#   val_dice_RC: 0.5838
#   val_dice_SNFH: 0.8647
#   val_dice_bg: 0.9969
#   val_dice_coef: 0.5967
#   val_dice_tumor_core: 0.8630
#   val_dice_whole_tumor: 0.8910
