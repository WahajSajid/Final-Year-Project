# %%
import requests

url = "https://storage.googleapis.com/kaggle-script-versions/303584850/output/training_brats2024.log?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260316%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260316T093327Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
r = requests.get(url)

with open("training_brats2024.log", "wb") as f:
    f.write(r.content)

print("Downloaded: training_brats_2024.log")
# Out:
# Downloaded: training_brats_2024.log
