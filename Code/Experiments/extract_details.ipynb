# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Wahaj Sajid\Desktop\Python\training_brats__2024.txt")
latest = df.iloc[-1]

train_cols = ['dice_ET','dice_NETC','dice_RC','dice_SNFH','dice_bg','dice_coef','dice_tumor_core','dice_whole_tumor']
val_cols   = ['val_dice_ET','val_dice_NETC','val_dice_RC','val_dice_SNFH','val_dice_bg','val_dice_coef','val_dice_tumor_core','val_dice_whole_tumor']

print(f"Epoch: {int(latest['epoch'])}\n")
print("Training:")
for c in train_cols:
    print(f"  {c}: {latest[c]:.4f}")

print("\nValidation:")
for c in val_cols:
    print(f"  {c}: {latest[c]:.4f}")
# Out:
# Epoch: 75
#
# Training:
#   dice_ET: 0.4526
#   dice_NETC: 0.8839
#   dice_RC: 0.7863
#   dice_SNFH: 0.8532
#   dice_bg: 0.9969
#   dice_coef: 0.7541
#   dice_tumor_core: 0.8881
#   dice_whole_tumor: 0.9037
#
# Validation:
#   val_dice_ET: 0.4450
#   val_dice_NETC: 0.8884
#   val_dice_RC: 0.7376
#   val_dice_SNFH: 0.8473
#   val_dice_bg: 0.9959
#   val_dice_coef: 0.7093
#   val_dice_tumor_core: 0.8966
#   val_dice_whole_tumor: 0.9089
